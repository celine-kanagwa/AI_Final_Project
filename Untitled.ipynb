# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score

import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# ## DATA COLLECTION

# %%
#loading the breast cancer dataset from csv file to pandas data frame
Dataset = pd.read_csv("data.csv")

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %%
Dataset.head(2)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
# 1  842517         M        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
# 1  ...          23.41            158.8      1956.0            0.1238
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
#
# [2 rows x 33 columns]

# %%
Dataset.shape
# Out:
# (569, 33)

# %%
#checking the data type
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
#statistical summary of the data_Sescriptive Statostics 
Dataset.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  texture_worst  perimeter_worst   area_worst  \
# count     569.000000  ...     569.000000       569.000000   569.000000
# mean        0.181162  ...      25.677223       107.261213   880.583128
# std         0.027414  ...       6.146258        33.602542   569.356993
# min         0.106000  ...      12.020000        50.410000   185.200000
# 25%         0.161900  ...      21.080000        84.110000   515.300000
# 50%         0.179200  ...      25.410000        97.660000   686.500000
# 75%         0.195700  ...      29.720000       125.400000  1084.000000
# max         0.304000  ...      49.540000       251.200000  4254.000000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        569.000000         569.000000       569.000000
# mean           0.132369           0.254265         0.272188
# std            0.022832           0.157336         0.208624
# min            0.071170           0.027290         0.000000
# 25%            0.116600           0.147200         0.114500
# 50%            0.131300           0.211900         0.226700
# 75%            0.146000           0.339100         0.382900
# max            0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst  \
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
#        Unnamed: 32
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 32 columns]

# %%
#checking for null values
Dataset.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
Dataset.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
#handling missing values by droping unnamed column, and removing id
Dataset.drop(columns=['Unnamed: 32', 'id'], axis = 1, inplace=True)

# %%
Dataset.shape
# Out:
# (569, 31)

# %%
#checking the of tarfed variable (diagnsis)
Dataset['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# B: Benign = 357 rows
# M: Malignant 212 rows

# %%
#Encoding the target column
label_encode = LabelEncoder()
labels = label_encode.fit_transform(Dataset['diagnosis'])
Dataset['diagnosis']= labels

# %%
Dataset['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# B: Benign = 357 rows-->0
# M: Malignant 212 rows -->1

# %% [markdown]
# ### DATA VISUALIZATION

# %%
Dataset.groupby('diagnosis').mean()
# Out:
#            radius_mean  texture_mean  perimeter_mean   area_mean  \
# diagnosis
# B            12.146524     17.914762       78.075406  462.790196
# M            17.462830     21.604906      115.365377  978.376415
#
#            smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# B                 0.092478          0.080085        0.046058
# M                 0.102898          0.145188        0.160775
#
#            concave points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# diagnosis                                                              ...
# B                     0.025717       0.174186                0.062867  ...
# M                     0.087990       0.192909                0.062680  ...
#
#            radius_worst  texture_worst  perimeter_worst   area_worst  \
# diagnosis
# B             13.379801      23.515070        87.005938   558.899440
# M             21.134811      29.318208       141.370330  1422.286321
#
#            smoothness_worst  compactness_worst  concavity_worst  \
# diagnosis
# B                  0.124959           0.182673         0.166238
# M                  0.144845           0.374824         0.450606
#
#            concave points_worst  symmetry_worst  fractal_dimension_worst
# diagnosis
# B                      0.074444        0.270246                 0.079442
# M                      0.182237        0.323468                 0.091530
#
# [2 rows x 30 columns]

# %%
sns.countplot(x='diagnosis', data=Dataset)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
# creating a for loop to get the distribution plot for all columns
#for column in Dataset:
#  sns.displot(x=column, data=Dataset)

# %%
corr = Dataset.corr() # .corr is used for find corelation
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_366cf_row0_col0, #T_366cf_row0_col2, #T_366cf_row1_col1, #T_366cf_row2_col0, #T_366cf_row2_col2, #T_366cf_row3_col3, #T_366cf_row4_col4, #T_366cf_row5_col5, #T_366cf_row6_col6, #T_366cf_row7_col7, #T_366cf_row8_col8, #T_366cf_row9_col9, #T_366cf_row10_col10, #T_366cf_row11_col11, #T_366cf_row12_col12, #T_366cf_row13_col13, #T_366cf_row14_col14, #T_366cf_row15_col15, #T_366cf_row16_col16, #T_366cf_row17_col17, #T_366cf_row18_col18, #T_366cf_row19_col19, #T_366cf_row20_col20, #T_366cf_row21_col21, #T_366cf_row22_col22, #T_366cf_row23_col23, #T_366cf_row24_col24, #T_366cf_row25_col25, #T_366cf_row26_col26, #T_366cf_row27_col27, #T_366cf_row28_col28, #T_366cf_row29_col29 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col1, #T_366cf_row4_col2, #T_366cf_row4_col20, #T_366cf_row4_col22, #T_366cf_row24_col22, #T_366cf_row27_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_366cf_row0_col3, #T_366cf_row2_col3, #T_366cf_row3_col0, #T_366cf_row3_col2 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col4, #T_366cf_row11_col12, #T_366cf_row12_col24, #T_366cf_row13_col16 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col5, #T_366cf_row1_col20, #T_366cf_row4_col6, #T_366cf_row19_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_366cf_row0_col6, #T_366cf_row5_col2, #T_366cf_row6_col13, #T_366cf_row23_col6 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_366cf_row0_col7, #T_366cf_row3_col7, #T_366cf_row3_col13, #T_366cf_row4_col24, #T_366cf_row25_col29, #T_366cf_row27_col2, #T_366cf_row27_col25 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col8, #T_366cf_row1_col17 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col9, #T_366cf_row0_col19, #T_366cf_row1_col4, #T_366cf_row1_col8, #T_366cf_row9_col0, #T_366cf_row9_col1, #T_366cf_row9_col2, #T_366cf_row9_col3, #T_366cf_row9_col10, #T_366cf_row9_col12, #T_366cf_row9_col13, #T_366cf_row9_col20, #T_366cf_row9_col23, #T_366cf_row11_col5, #T_366cf_row11_col6, #T_366cf_row11_col7, #T_366cf_row11_col24, #T_366cf_row11_col25, #T_366cf_row11_col26, #T_366cf_row11_col27, #T_366cf_row11_col28, #T_366cf_row11_col29, #T_366cf_row14_col21, #T_366cf_row14_col22, #T_366cf_row18_col21, #T_366cf_row20_col14, #T_366cf_row20_col18, #T_366cf_row21_col15, #T_366cf_row21_col16, #T_366cf_row21_col17, #T_366cf_row28_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col10, #T_366cf_row28_col8 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_366cf_row0_col11 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col12, #T_366cf_row5_col22, #T_366cf_row15_col26, #T_366cf_row20_col6, #T_366cf_row26_col20 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_366cf_row0_col13, #T_366cf_row6_col3, #T_366cf_row10_col0, #T_366cf_row10_col2, #T_366cf_row12_col2 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_366cf_row0_col14, #T_366cf_row14_col7, #T_366cf_row20_col19, #T_366cf_row27_col11 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col15, #T_366cf_row20_col15, #T_366cf_row28_col12, #T_366cf_row29_col11 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col16, #T_366cf_row4_col21, #T_366cf_row11_col15, #T_366cf_row11_col16, #T_366cf_row24_col18, #T_366cf_row27_col14 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col17, #T_366cf_row5_col18, #T_366cf_row10_col4, #T_366cf_row12_col15, #T_366cf_row15_col11, #T_366cf_row17_col11, #T_366cf_row21_col28, #T_366cf_row24_col3 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_366cf_row0_col18, #T_366cf_row2_col14, #T_366cf_row3_col9, #T_366cf_row3_col19, #T_366cf_row21_col8, #T_366cf_row22_col11, #T_366cf_row22_col18 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col20, #T_366cf_row2_col20, #T_366cf_row2_col22, #T_366cf_row12_col10, #T_366cf_row20_col2, #T_366cf_row22_col0, #T_366cf_row22_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col21, #T_366cf_row1_col26, #T_366cf_row10_col25, #T_366cf_row13_col25, #T_366cf_row14_col4, #T_366cf_row15_col13, #T_366cf_row17_col8, #T_366cf_row27_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_366cf_row0_col22, #T_366cf_row3_col20, #T_366cf_row10_col12, #T_366cf_row20_col3 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col23, #T_366cf_row2_col23, #T_366cf_row13_col10 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col24, #T_366cf_row6_col11, #T_366cf_row29_col1, #T_366cf_row29_col18 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col25, #T_366cf_row4_col28, #T_366cf_row6_col8, #T_366cf_row8_col29, #T_366cf_row15_col14, #T_366cf_row15_col18, #T_366cf_row16_col29, #T_366cf_row17_col13, #T_366cf_row21_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_366cf_row0_col26, #T_366cf_row4_col27, #T_366cf_row28_col27, #T_366cf_row28_col29 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_366cf_row0_col27, #T_366cf_row10_col20, #T_366cf_row10_col22, #T_366cf_row12_col22, #T_366cf_row19_col15 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_366cf_row0_col28, #T_366cf_row9_col11, #T_366cf_row10_col16, #T_366cf_row10_col19, #T_366cf_row12_col8, #T_366cf_row12_col21 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_366cf_row0_col29, #T_366cf_row1_col16, #T_366cf_row3_col18, #T_366cf_row3_col29, #T_366cf_row4_col1, #T_366cf_row24_col11, #T_366cf_row29_col10, #T_366cf_row29_col12 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_366cf_row1_col0, #T_366cf_row6_col24, #T_366cf_row9_col15, #T_366cf_row17_col20, #T_366cf_row23_col5, #T_366cf_row23_col25, #T_366cf_row25_col4, #T_366cf_row28_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_366cf_row1_col2, #T_366cf_row1_col23, #T_366cf_row8_col24, #T_366cf_row10_col17, #T_366cf_row14_col11, #T_366cf_row17_col23 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_366cf_row1_col3, #T_366cf_row1_col22, #T_366cf_row4_col26, #T_366cf_row6_col19, #T_366cf_row8_col26, #T_366cf_row21_col23 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_366cf_row1_col5, #T_366cf_row10_col24, #T_366cf_row19_col2, #T_366cf_row19_col13 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_366cf_row1_col6, #T_366cf_row29_col0, #T_366cf_row29_col17 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_366cf_row1_col7, #T_366cf_row9_col17, #T_366cf_row15_col24, #T_366cf_row19_col8, #T_366cf_row21_col24, #T_366cf_row23_col17, #T_366cf_row24_col21 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_366cf_row1_col9, #T_366cf_row13_col28, #T_366cf_row19_col22, #T_366cf_row22_col29 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_366cf_row1_col10, #T_366cf_row12_col19, #T_366cf_row21_col7, #T_366cf_row29_col20, #T_366cf_row29_col21 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_366cf_row1_col11, #T_366cf_row12_col26, #T_366cf_row17_col14 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_366cf_row1_col12, #T_366cf_row10_col21, #T_366cf_row21_col29, #T_366cf_row29_col23 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_366cf_row1_col13, #T_366cf_row4_col17, #T_366cf_row10_col14 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_366cf_row1_col14, #T_366cf_row18_col5, #T_366cf_row21_col10 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_366cf_row1_col15, #T_366cf_row3_col11, #T_366cf_row18_col24, #T_366cf_row21_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_366cf_row1_col18, #T_366cf_row14_col8, #T_366cf_row19_col1, #T_366cf_row20_col8 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_366cf_row1_col19, #T_366cf_row2_col29, #T_366cf_row10_col29, #T_366cf_row14_col3, #T_366cf_row14_col5, #T_366cf_row18_col22 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_366cf_row1_col21, #T_366cf_row6_col7, #T_366cf_row7_col27, #T_366cf_row21_col1 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_366cf_row1_col24, #T_366cf_row2_col16, #T_366cf_row14_col29, #T_366cf_row18_col2

# %%
Dataset.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
Dataset.drop(columns=['fractal_dimension_mean','texture_se','smoothness_se','symmetry_se',
       'fractal_dimension_se'], axis = 1, inplace=True)

# %%
Dataset.shape
# Out:
# (569, 26)

# %% [markdown]
# ### MODEL BUILDING

# %%
#splitting data into training and test data 
X = Dataset.drop(columns='diagnosis', axis=1)
Y = Dataset['diagnosis']

# %%
#Splitting the data into training data & Testing data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)
print( X_train.shape, X_test.shape,Y_train.shape, Y_test.shape)
# Out:
# (455, 25) (114, 25) (455,) (114,)

# %%
#Standardize the data
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

# %% [markdown]
# #### 1.LOGISTC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
Lr_model = LogisticRegression()

# %%
# training the Logistic Regression model using
Lr_model.fit(X_train_std, Y_train)
# Out:
# LogisticRegression()

# %%
# accuracy on training data
X_train_prediction = Lr_model.predict(X_train_std,)
# accuracy on test data
X_test_prediction = Lr_model.predict(X_test_std)

# %%
print('Accuracy on training data =', accuracy_score( X_train_prediction,Y_train))
print('Accuracy on test data = ',   accuracy_score( X_test_prediction,Y_test))
# Out:
# Accuracy on training data = 0.989010989010989
# Accuracy on test data =  0.9824561403508771

# %%
#evaluating the model 
print(confusion_matrix(Y_test,X_test_prediction))
# Out:
# [[68  1]
#  [ 1 44]]

# %%
cm = confusion_matrix(Y_test,X_test_prediction)
sns.heatmap(cm, annot=True)
#plt.savefig('confusion.png')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 2. RONDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
#rf_model = RandomForestClassifier(random_state=42)
rf_model = RandomForestClassifier(n_estimators=17, random_state=42)

# %%
# Fit on training data
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(n_estimators=17, random_state=42)

# %%
X_train_rf_prediction = rf_model.predict(X_train)
X_test_rf_prediction = rf_model.predict(X_test)

# %%
print('Accuracy on training data = ', accuracy_score(Y_train, X_train_rf_prediction))
print('Accuracy on test data = ',accuracy_score(Y_test, X_test_rf_prediction))
# Out:
# Accuracy on training data =  1.0
# Accuracy on test data =  0.9385964912280702

# %%
#evaluating the model 
cm = confusion_matrix(Y_test,X_test_rf_prediction)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(Y_test,X_test_rf_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.96      0.94      0.95        69
#            M       0.91      0.93      0.92        45
#
#     accuracy                           0.94       114
#    macro avg       0.93      0.94      0.94       114
# weighted avg       0.94      0.94      0.94       114

# %% [markdown]
# #### 3.SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVC
svm_model = SVC()

# %%
svm_model.fit(X_train_std,Y_train)
svm_predictionmtrain=svm_model.predict(X_train_std)
svm_prediction=svm_model.predict(X_test_std)

# %%
print('Accuracy on training data = ', accuracy_score(svm_predictionmtrain,Y_train))
print('Accuracy on test data = ', accuracy_score(svm_prediction,Y_test))
# Out:
# Accuracy on training data =  0.9846153846153847
# Accuracy on test data =  0.9649122807017544

# %%
cm = confusion_matrix(Y_test,svm_prediction)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 4.K_NEAREST NEIGHBORS

# %%
#fitting classifier model into training test
from sklearn.neighbors import KNeighborsClassifier
Knn_model = KNeighborsClassifier(n_neighbors=3,metric='minkowski')
Knn_model.fit(X_train_std,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
Knn_predictiontrain=Knn_model.predict(X_train_std)
knn_prediction=Knn_model.predict(X_test_std)
knn_prediction
# Out:
# array(['B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M',
#        'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M'], dtype=object)

# %%
print('Accuracy on training data = ', accuracy_score(Knn_predictiontrain,Y_train))
print('Accuracy on test data = ', accuracy_score(knn_prediction,Y_test))
# Out:
# Accuracy on training data =  0.9802197802197802
# Accuracy on test data =  0.9736842105263158

# %%
cm = confusion_matrix(Y_test,knn_prediction)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
#Prediction on train data 
predictions_df = pd.DataFrame(Y_test)
predictions_df['Logistic Regression'] = accuracy_score( X_train_prediction,Y_train)
predictions_df['Random Forrest Regressor'] = accuracy_score(Y_train, X_train_rf_prediction)
predictions_df['SVM'] = accuracy_score(svm_predictionmtrain,Y_train)
predictions_df['KNN'] =accuracy_score(Knn_predictiontrain,Y_train)

# %%
predictions_df.head(2)
# Out:
#     diagnosis  Logistic Regression  Random Forrest Regressor       SVM  \
# 528         B             0.989011                       1.0  0.984615
# 291         B             0.989011                       1.0  0.984615
#
#          KNN
# 528  0.98022
# 291  0.98022

# %%
#Prediction on test data 
predictions_df = pd.DataFrame(Y_test)
predictions_df['Logistic Regression'] = accuracy_score( X_test_prediction,Y_test)
predictions_df['Random Forrest Regressor'] = accuracy_score(Y_test, X_test_rf_prediction)
predictions_df['SVM'] = accuracy_score(svm_prediction,Y_test)
predictions_df['KNN'] = accuracy_score(knn_prediction,Y_test)

# %%
predictions_df.head(2)
# Out:
#     diagnosis  Logistic Regression  Random Forrest Regressor       SVM  \
# 528         B             0.982456                  0.938596  0.964912
# 291         B             0.982456                  0.938596  0.964912
#
#           KNN
# 528  0.973684
# 291  0.973684

# %% [markdown]
# #### Building a predictive model

# %%
input_data = (0.08129,0.06664,0.04781,0.1885,0.05766,0.08129,0.06664,0.04781,0.1885,0.05766,0.2699,0.7886,2.058,23.56,0.0146,0.01315,15.11,19.26,99.7,711.2,0.1773,0.239,0.1288,0.2977,0.07259)
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
prediction = Lr_model.predict(input_data_reshaped)
print(prediction)
#23.54,24.36,107.46,766.3,0.09779
# Out:
# ['M']

# %%
if (prediction[0] == 0):
  print('The Breast cancer is Malignant')

else:
  print('The Breast Cancer is Benign')
# Out:
# The Breast Cancer is Benign

# %% [markdown]
# #### SAVING MODEL

# %%
import pickle

# %%
with open ('Breast_cancer_model.pkl', 'wb')as f:
    pickle.dump(Lr_model, f)
    
with open ('Breast_cancer_model.pkl', 'rb')as f: 
    Lr_model = pickle.load(f)

# %% [markdown]
# ##### FEATURE SELECTION

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
# Feature Importance 
X_Train_new = SelectKBest(chi2, k=20).fit_transform(X,Y)
x_train_new,x_test_new,y_train_new, y_test_new = train_test_split(X_Train_new,Y, test_size=0.2, random_state=42)

# %%
X_train_new = scaler.fit_transform(x_train_new)
X_test_new =scaler.fit_transform(x_test_new)

# %% [markdown]
# #### For logistic regression

# %%
Lr_model.fit(X_train_new,y_train_new)
# Out:
# LogisticRegression()

# %%
# accuracy on training data
X_train_prediction_new = Lr_model.predict(X_train_new)
# accuracy on test data
X_test_prediction_new = Lr_model.predict(X_test_new)

# %%
print('Accuracy on training data = ', accuracy_score(y_train_new, X_train_prediction_new ))
print('Accuracy on test data = ',accuracy_score(y_test_new, X_test_prediction_new))
# Out:
# Accuracy on training data =  0.9758241758241758
# Accuracy on test data =  0.9824561403508771

# %% [markdown]
# #### for Rondom forest

# %%
rf_model = RandomForestClassifier( random_state=42)
# Fit on training data
rf_model.fit(X_train_new,y_train_new)
# Out:
# RandomForestClassifier(random_state=42)

# %%
X_train_rf_pred_rf = rf_model.predict(X_train_new)
X_test_rf_predi_rf= rf_model.predict(X_test_new)

# %%
print('Accuracy on training data = ', accuracy_score(y_train_new, X_train_rf_pred_rf))
print('Accuracy on test data = ',accuracy_score(y_test_new, X_test_rf_predi_rf))
# Out:
# Accuracy on training data =  1.0
# Accuracy on test data =  0.956140350877193

# %% [markdown]
# #### PRINCIPAL COMPONENT ANALYSIS

# %%
from sklearn.decomposition import PCA 
pca = PCA(n_components = 2)
pca.fit (X_train_std)
# Out:
# PCA(n_components=2)

# %%
X_pca = pca.transform(X_train_std)

# %%
X_train_std .shape
# Out:
# (455, 25)

# %%
X_pca.shape
# Out:
# (455, 2)

# %%
X_pca[:0], X_pca[:1],
# Out:
# (array([], shape=(0, 2), dtype=float64), array([[-0.48575124,  0.56432684]]))

# %%
target_names = ['B', 'M']
plt.figure(figsize=(8,6))
#plt.scatter(X_pca[:0], X_pca[:1],target_names['diagnosis'])
X=X_pca[:0]
Y=X_pca[:1]
plt.scatter(X,Y, target_names[diagnosis])
plt.xlable('first principal component')
plt.ylabel('second principal component')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20004/3121398177.py in <module>
#       4 X=X_pca[:0]
#       5 Y=X_pca[:1]
# ----> 6 plt.scatter(X,Y, target_names[diagnosis])
#       7 plt.xlable('first principal component')
#       8 plt.ylabel('second principal component')
#
# NameError: name 'diagnosis' is not defined
